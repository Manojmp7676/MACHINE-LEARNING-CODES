# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Manoj M P\OneDrive\Desktop\sample_employee_data.csv")
print(df.head())
# Out:
#    id   name   age   salary   join date     city
# 0   1   Ravi  22.0  50000.0  30-09-2017   Mumbai
# 1   2   Neha  27.0      NaN  23-12-2015     Pune
# 2   3  Vikas  23.0  30000.0  19-01-2016   Mumbai
# 3   4  Priya  53.0      NaN  19-04-2015     Pune
# 4   5  Priya  55.0  60000.0  21-06-2017  Chennai

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         50 non-null     int64
#  1   name       43 non-null     object
#  2   age        42 non-null     float64
#  3   salary     35 non-null     float64
#  4   join date  44 non-null     object
#  5   city       41 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#               id        age        salary
# count  50.000000  42.000000     35.000000
# mean   25.440000  39.833333  44571.428571
# std    14.602432  12.683611  10666.841735
# min     1.000000  21.000000  30000.000000
# 25%    13.250000  28.250000  35000.000000
# 50%    25.500000  37.000000  50000.000000
# 75%    37.750000  52.000000  50000.000000
# max    50.000000  59.000000  60000.000000

# %%
df.isnull().sum()
# Out:
# id            0
# name          7
# age           8
# salary       15
# join date     6
# city          9
# dtype: int64

# %%
df.isnull().sum().plot(kind='bar')
plt.show()

# %%
df['city']=df['city'].fillna(df['city'].mode()[0])

# %%
df['city'].isnull().sum()
# Out:
# 0

# %%
df['city']=df['city'].fillna(df['city'].mode()[0])

# %%
df['city'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#     id    name   age   salary   join date       city
# 0    1    Ravi  22.0  50000.0  30-09-2017     Mumbai
# 1    2    Neha  27.0      NaN  23-12-2015       Pune
# 2    3   Vikas  23.0  30000.0  19-01-2016     Mumbai
# 3    4   Priya  53.0      NaN  19-04-2015       Pune
# 4    5   Priya  55.0  60000.0  21-06-2017    Chennai
# 5    6   Kiran   NaN  50000.0  27-01-2015        NaN
# 6    7     NaN  31.0  60000.0  25-10-2018  Bangalore
# 7    8    Neha  34.0  50000.0         NaN      Delhi
# 8    9    Ravi  45.0  30000.0  10-01-2019        NaN
# 9    9   Anita  59.0  50000.0  27-06-2015  Hyderabad
# 10  11   Pooja  55.0  30000.0  31-03-2019      Delhi
# 11  12   Rahul   NaN  50000.0  18-01-2022       Pune
# 12  13   Anita  57.0  40000.0  25-11-2022      Delhi
# 13  14     NaN  23.0  40000.0  31-03-2018      Delhi
# 14  15   Priya  27.0  60000.0  12-02-2018    Chennai
# 15  16   Anita  31.0  50000.0         NaN  Bangalore
# 16  17   Priya  38.0  30000.0  31-10-2021  Hyderabad
# 17  18    Neha   NaN      NaN  06-03-2023     Mumbai
# 18  19    Neha  50.0  60000.0  10-01-2018  Hyderabad
# 19  19   Rahul  35.0  50000.0  18-08-2015     Mumbai
# 20  21     NaN  23.0  50000.0  02-07-2019  Bangalore
# 21  22    Ravi  34.0      NaN  19-01-2023  Bangalore
# 22  23   Priya  52.0  60000.0  18-03-2022    Chennai
# 23  24    Neha   NaN  50000.0         NaN     Mumbai
# 24  25   Priya  56.0      NaN  12-12-2017  Hyderabad
# 25  26   Kiran  48.0      NaN  24-06-2019  Bangalore
# 26  27   Priya  29.0      NaN  14-07-2020      Delhi
# 27  28     NaN  24.0  30000.0  18-09-2016  Hyderabad
# 28  29    Neha  48.0      NaN  18-09-2015    Chennai
# 29  29   Vikas   NaN      NaN  01-04-2020       Pune
# 30  31  Suresh  56.0  30000.0  18-08-2022  Hyderabad
# 31  32    Ravi  55.0  50000.0         NaN        NaN
# 32  33   Anita  28.0  50000.0  16-11-2019     Mumbai
# 33  34   Pooja  21.0  50000.0  12-08-2020        NaN
# 34  35     NaN  32.0      NaN  11-03-2016        NaN
# 35  36  Suresh   NaN      NaN  30-10-2021     Mumbai
# 36  37    Neha  44.0  40000.0  18-01-2021        NaN
# 37  38   Rahul  21.0      NaN  20-08-2018    Chennai
# 38  39    Amit  28.0  50000.0  13-06-2018     Mumbai
# 39  40    Amit  36.0      NaN         NaN      Delhi
# 40  41    Ravi  52.0  30000.0  21-12-2020        NaN
# 41  42     NaN   NaN  40000.0  09-06-2016  Hyderabad
# 42  43   Pooja  56.0  40000.0  21-12-2017       Pune
# 43  44   Kiran  48.0  40000.0  17-01-2021        NaN
# 44  45   Priya  40.0  60000.0  14-07-2022  Hyderabad
# 45  46   Anita  49.0      NaN  24-01-2020      Delhi
# 46  47   Priya  35.0  30000.0  16-10-2018      Delhi
# 47  48   Kiran   NaN      NaN         NaN     Mumbai
# 48  49     NaN  58.0  40000.0  30-01-2015      Delhi
# 49  50    Amit  35.0  30000.0  09-05-2015        NaN

# %%
df['salary'] = pd.to_numeric(df['salary'], errors='coerce')
df['salary'].plot(kind='bar')
plt.show()

# %%
df['salary']=df['salary'].fillna(df['salary'].median())

# %%
df['join_date']=pd.to_datetime(df['join_date'],errors='coerce')
df['join_date']=df['join_date'].fillna(pd.Timestamp.today())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Manoj M P\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Manoj M P\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Manoj M P\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'join_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df['join_date']=pd.to_datetime(df['join_date'],errors='coerce')
#       2 df['join_date']=df['join_date'].fillna(pd.Timestamp.today())
#
# File c:\Users\Manoj M P\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\Manoj M P\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'join_date'
