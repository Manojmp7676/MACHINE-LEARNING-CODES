# %%
class ScratchLR:
    def __init__(self):
        self.m = None
        self.b = None
    def fit(self,x_train,y_train):    
        self.b=0.0
        numerator,denominator=0.0,0.0
        for i in len(x_train):
            numerator += (x[i]-x.mean())*(y[i]-y.mean())
            denominator += (x[i]-x.mean())**2
        self.m = numerator/denominator
        self.b = y.mean() - self.m*x.mean()
    def predict(self,x_test):
        return self.m*x_test + self.b

# %%
x=[1,2,3,5,7,9,12,13,15,18,20,22,25,27,29]
y=[2,4,7,8,12,15,16,18,19,20,22,25,28,30,35]
assert len(x) == len(y)

# %%
x_train,y_train,x_test,y_test=x[:11],y[:11],x[11:],y[11:]
print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
# [1, 2, 3, 5, 7, 9, 12, 13, 15, 18, 20]
# [2, 4, 7, 8, 12, 15, 16, 18, 19, 20, 22]
# [22, 25, 27, 29]
# [25, 28, 30, 35]

# %%
our_model = ScratchLR()
our_model.fit(x_train=x_train,y_train=y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 our_model = ScratchLR()
# ----> 2 our_model.fit(x_train=x_train,y_train=y_train)
#
# Cell In[1], line 8, in ScratchLR.fit(self, x_train, y_train)
#       6 self.b=0.0
#       7 numerator,denominator=0.0,0.0
# ----> 8 for i in len(x_train):
#       9     numerator += (x[i]-x.mean())*(y[i]-y.mean())
#      10     denominator += (x[i]-x.mean())**2
#
# TypeError: 'int' object is not iterable

# %%
print(sklr.intercept_)
print(sklr.coef_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(sklr.intercept_)
#       2 print(sklr.coef_)
#
# NameError: name 'sklr' is not defined

# %% [markdown]
# hii i love
